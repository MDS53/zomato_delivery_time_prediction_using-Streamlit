# %% [markdown]
# ## Dataset Location : 'c:\\Users\\new\\OneDrive\\Desktop\\Zomato project\\Notebooks\\Data'

# %%
import pandas as pd

# %%
df=pd.read_csv('c:\\Users\\new\\OneDrive\\Desktop\\Zomato project\\Notebooks\\Data\\zomato.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      ID Delivery_person_ID  Delivery_person_Age  \
# 0           0  0xcdcd      DEHRES17DEL01                 36.0
# 1           1  0xd987      KOCRES16DEL01                 21.0
# 2           2  0x2784     PUNERES13DEL03                 23.0
# 3           3  0xc8b6     LUDHRES15DEL02                 34.0
# 4           4  0xdb64      KNPRES14DEL02                 24.0
#
#    Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                      4.2            30.327968             78.046106
# 1                      4.7            10.003064             76.307589
# 2                      4.7            18.562450             73.916619
# 3                      4.3            30.899584             75.809346
# 4                      4.7            26.463504             80.372929
#
#    Delivery_location_latitude  Delivery_location_longitude  Order_Date  ...  \
# 0                   30.397968                    78.116106  12-02-2022  ...
# ...

# %% [markdown]
# # RUN

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.shape
# Out:
# (45584, 20)

# %%
max(df[df.columns[3]])
# Out:
# 6.0

# %%
df.columns[3]
# Out:
# 'Delivery_person_Ratings'

# %%
len(df[df[df.columns[3]]==max(df[df.columns[3]])])
# Out:
# 53

# %%
df[df[df.columns[3]]==max(df[df.columns[3]])]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3577    0x46d     BANGRES05DEL01                 50.0
# 4705    0x493      HYDRES17DEL01                 50.0
# 5160    0x4f2      JAPRES08DEL01                 50.0
# 5353    0x430     BANGRES19DEL01                 50.0
# 5642   0xbef1      AGRRES13DEL02                 50.0
# 6385    0x427      JAPRES06DEL02                 50.0
# 7022    0x3eb      MYSRES15DEL02                 50.0
# 7672    0xd42      VADRES09DEL01                 50.0
# 9490    0x3f0    BANGRES010DEL01                 50.0
# 9526    0x3ef   RANCHIRES13DEL01                 50.0
# 10091   0x5b0      MYSRES04DEL01                 50.0
# 10728  0xbffc      DEHRES18DEL02                 50.0
# 12288   0x940      SURRES02DEL02                 50.0
# 13248   0x490    COIMBRES03DEL02                 50.0
# 13643   0x434   RANCHIRES01DEL02                 50.0
# 14097   0x3f6      MYSRES06DEL02                 50.0
# ...

# %%
len(df[df[df.columns[3]]>5.0])
# Out:
# 53

# %%
df[df[df.columns[3]]>5.0]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3577    0x46d     BANGRES05DEL01                 50.0
# 4705    0x493      HYDRES17DEL01                 50.0
# 5160    0x4f2      JAPRES08DEL01                 50.0
# 5353    0x430     BANGRES19DEL01                 50.0
# 5642   0xbef1      AGRRES13DEL02                 50.0
# 6385    0x427      JAPRES06DEL02                 50.0
# 7022    0x3eb      MYSRES15DEL02                 50.0
# 7672    0xd42      VADRES09DEL01                 50.0
# 9490    0x3f0    BANGRES010DEL01                 50.0
# 9526    0x3ef   RANCHIRES13DEL01                 50.0
# 10091   0x5b0      MYSRES04DEL01                 50.0
# 10728  0xbffc      DEHRES18DEL02                 50.0
# 12288   0x940      SURRES02DEL02                 50.0
# 13248   0x490    COIMBRES03DEL02                 50.0
# 13643   0x434   RANCHIRES01DEL02                 50.0
# 14097   0x3f6      MYSRES06DEL02                 50.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
max(df['Time_taken (min)'])
# Out:
# 54

# %% [markdown]
#     Delivery_person_Age : int32
#     Delivery_person_Ratings : float32
#     Vehicle_condition : int32
#     multiple_deliveries :float32
#     Time_taken (min) : int32

# %% [markdown]
# # RUN

# %%
for i in ['Vehicle_condition','Time_taken (min)']:
    df[i]=df[i].astype('int32') 
    #print(i,df[i].isna().sum())

# %%
for i in ['Delivery_person_Ratings']:
    print(i,df[i].isna().sum())
    df[i]=df[i].astype('float32')
# Out:
# Delivery_person_Ratings 1908

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float32
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
len(df['ID'].unique())
# Out:
# 45584

# %% [markdown]
# # RUN

# %%
df.drop(['ID'],axis=1,inplace=True)

# %%
len(df['Delivery_person_ID'].unique())
# Out:
# 1320

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_ID           45584 non-null  object
#  1   Delivery_person_Age          43730 non-null  float64
#  2   Delivery_person_Ratings      43676 non-null  float64
#  3   Restaurant_latitude          45584 non-null  float64
#  4   Restaurant_longitude         45584 non-null  float64
#  5   Delivery_location_latitude   45584 non-null  float64
#  6   Delivery_location_longitude  45584 non-null  float64
#  7   Order_Date                   45584 non-null  object
#  8   Time_Orderd                  43853 non-null  object
#  9   Time_Order_picked            45584 non-null  object
#  10  Weather_conditions           44968 non-null  object
#  11  Road_traffic_density         44983 non-null  object
# ...

# %% [markdown]
# ## Basic Stats

# %%
df.isna().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
df.select_dtypes(include='object').describe()
# Out:
#        Delivery_person_ID  Order_Date Time_Orderd Time_Order_picked  \
# count               45584       45584       43853             45584
# unique               1320          44         176               193
# top         JAPRES11DEL02  15-03-2022       21:55             21:30
# freq                   67        1192         461               495
#
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle  \
# count               44968                44983         45584           45584
# unique                  6                    4             4               4
# top                   Fog                  Low         Snack      motorcycle
# freq                 7653                15476         11530           26429
#
#        Festival           City
# count     45356          44384
# unique        2              3
# top          No  Metropolitian
# freq      44460          34087

# %%
len(df['Order_Date'].value_counts())
# Out:
# 44

# %% [markdown]
# # Each Person no of orders per day

# %%
df.groupby(['Delivery_person_ID','Order_Date'])['Order_Date'].value_counts().sort_values(ascending=False).reset_index()
# Out:
#       Delivery_person_ID  Order_Date  count
# 0         AGRRES010DEL01  11-02-2022      2
# 1         LUDHRES13DEL02  17-02-2022      2
# 2         LUDHRES13DEL02  12-02-2022      2
# 3         LUDHRES13DEL01  18-02-2022      2
# 4         LUDHRES13DEL01  17-02-2022      2
# ...                  ...         ...    ...
# 28740    COIMBRES03DEL03  14-03-2022      1
# 28741      MUMRES14DEL01  12-03-2022      1
# 28742      MUMRES14DEL01  13-03-2022      1
# 28743    COIMBRES03DEL03  12-03-2022      1
# 28744      VADRES20DEL03  31-03-2022      1
#
# [28745 rows x 3 columns]

# %% [markdown]
# # Each Person no of orders w.r.t age

# %%
df.groupby(['Delivery_person_ID'])['Delivery_person_Age'].value_counts().sort_values(ascending=False).reset_index()
# Out:
#       Delivery_person_ID  Delivery_person_Age  count
# 0         INDORES08DEL02                 39.0     10
# 1          SURRES11DEL01                 35.0      9
# 2         CHENRES06DEL02                 29.0      9
# 3         PUNERES05DEL02                 35.0      9
# 4          SURRES13DEL02                 39.0      9
# ...                  ...                  ...    ...
# 18771      KOCRES14DEL02                 34.0      1
# 18772      KOCRES14DEL02                 35.0      1
# 18773      KOCRES14DEL02                 38.0      1
# 18774      KOCRES14DEL03                 38.0      1
# 18775      VADRES20DEL03                 38.0      1
#
# [18776 rows x 3 columns]

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df[df['Vehicle_condition']==3].sample(5)
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33851     JAPRES010DEL01                  NaN                      NaN
# 14623   RANCHIRES20DEL03                  NaN                      NaN
# 30048      MYSRES01DEL03                  NaN                      NaN
# 23904      JAPRES08DEL03                  NaN                      NaN
# 10771   RANCHIRES12DEL03                  NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 33851           -26.921411            -75.793604                   26.991411
# 14623            23.399250             85.390464                   23.459250
# 30048            12.311072             76.654878                   12.371072
# 23904            26.910262             75.783013                   27.000262
# 10771             0.000000              0.000000                    0.060000
#
# ...

# %% [markdown]
# # Calculating Distances using lattitudes,Longitudes using Haversine formula

# %%
from math import radians, sin, cos, sqrt, atan2
import numpy as np
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance between two points 
    on the earth specified in decimal degrees
    """
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    radius_of_earth = 6371  # Radius of Earth in kilometers
    distance = radius_of_earth * c

    return distance

# Example usage
lat1, lon1 = 12.311072	, 76.654878 # Latitude and longitude of Berlin, Germany
lat2, lon2 = 12.371072	, 76.714878   # Latitude and longitude of Paris, France

distance = haversine(lat1, lon1, lat2, lon2)
print("Distance:", np.round(distance,1), "km")
# Out:
# Distance: 9.3 km

# %%
df[df.columns[3:7]].head(5)
# Out:
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude
# 0                    78.116106
# 1                    76.347589
# 2                    74.006619
# 3                    75.829346
# 4                    80.502929

# %%
np.array(df[df.columns[3:7]])
# Out:
# array([[30.327968, 78.046106, 30.397968, 78.116106],
#        [10.003064, 76.307589, 10.043064, 76.347589],
#        [18.56245 , 73.916619, 18.65245 , 74.006619],
#        ...,
#        [13.022394, 80.242439, 13.052394, 80.272439],
#        [11.001753, 76.986241, 11.041753, 77.026241],
#        [23.351058, 85.325731, 23.431058, 85.405731]])

# %% [markdown]
# # RUN

# %%
h=[]

# %%
type(k)
# Out:
# list

# %%
k.append

# %%
for i,j,k,l in np.array(df[df.columns[3:7]]):
    #print(i,j,k,l)
    distance = haversine(i,j,k,l)
    h.append(np.round(distance,1))
    print("Distance:", np.round(distance,1), "km")
# Out:
# Distance: 10.3 km
# Distance: 6.2 km
# Distance: 13.8 km
# Distance: 2.9 km
# Distance: 19.4 km
# Distance: 13.8 km
# Distance: 6.2 km
# Distance: 16.8 km
# Distance: 10.8 km
# Distance: 4.5 km
# Distance: 12.3 km
# Distance: 19.6 km
# Distance: 1.6 km
# Distance: 20.2 km
# Distance: 6.1 km
# Distance: 17.1 km
# Distance: 4.5 km
# Distance: 13.7 km
# Distance: 14.0 km
# Distance: 16.9 km
# Distance: 4.7 km
# Distance: 7.6 km
# Distance: 7.7 km
# Distance: 6.2 km
# Distance: 17.3 km
# Distance: 19.9 km
# Distance: 10.7 km
# Distance: 6.1 km
# Distance: 1.5 km
# Distance: 3.1 km
# Distance: 3.1 km
# Distance: 10.9 km
# Distance: 10.9 km
# Distance: 12.2 km
# Distance: 13.7 km
# Distance: 16.8 km
# Distance: 3.0 km
# Distance: 9.2 km
# Distance: 9.3 km
# Distance: 6.2 km
# Distance: 1.5 km
# Distance: 6.0 km
# Distance: 17.1 km
# Distance: 4.7 km
# Distance: 12.5 km
# Distance: 9.1 km
# Distance: 14.0 km
# Distance: 13.4 km
# Distance: 12.6 km
# Distance: 1.5 km
# Distance: 9.4 km
# ...

# %%
len(h)
# Out:
# 45584

# %%
df.shape
# Out:
# (45584, 19)

# %%
df['Distance in kms']=h

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Order_Date Time_Orderd Time_Order_picked Weather_conditions  \
# 0  12-02-2022       21:55             22:10                Fog
# 1  13-02-2022       14:55             15:05             Stormy
# 2  04-03-2022       17:30             17:40         Sandstorms
# 3  13-02-2022       09:20             09:30         Sandstorms
# 4  14-02-2022       19:50             20:05                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
# ...

# %%
df.isna().sum()
# Out:
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# Distance in kms                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings',
#        'Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Order_Date', 'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)', 'Distance in kms'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings',
#        'Order_Date', 'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)', 'Distance in kms'],
#       dtype='object')

# %%
import seaborn as sns

# %%
d=df.groupby([df.columns[1],df.columns[-2],df.columns[-1]])[df.columns[1]].value_counts().sort_values(ascending=False).reset_index()

# %%
d
# Out:
#        Delivery_person_Age  Time_taken (min)  Distance in kms  count
# 0                     38.0                26              1.5     18
# 1                     20.0                16              3.1     18
# 2                     28.0                15              3.1     16
# 3                     28.0                15              1.5     16
# 4                     32.0                22              1.5     16
# ...                    ...               ...              ...    ...
# 22837                 28.0                31              3.1      1
# 22838                 28.0                31              4.5      1
# 22839                 28.0                31              6.3      1
# 22840                 28.0                31              9.0      1
# 22841                 50.0                48             17.3      1
#
# [22842 rows x 4 columns]

# %%
d.plot(kind='line')
# Out:
# <Axes: >

# %%
d.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.pairplot(d)
# Out:
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[df['Distance in kms']<1.6]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 28         SURRES08DEL01                 20.0                      4.8
# 40         SURRES09DEL01                 33.0                      5.0
# 49         JAPRES14DEL01                 32.0                      4.5
# 82      RANCHIRES17DEL01                 32.0                      4.6
# 121        SURRES14DEL01                 26.0                      5.0
# ...                  ...                  ...                      ...
# 45510      AGRRES07DEL01                  NaN                      NaN
# 45518      SURRES19DEL01                 33.0                      4.7
# 45541     INDORES04DEL01                 23.0                      4.6
# 45556   RANCHIRES20DEL01                 24.0                      4.5
# 45579      JAPRES04DEL01                 30.0                      4.8
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
sns.scatterplot(x=d[d.columns[1]],y=d[d.columns[2]],hue=d[d.columns[0]])
# Out:
# <Axes: xlabel='Time_taken (min)', ylabel='Distance in kms'>

# %%
d[d.columns[0]].unique()
# Out:
# array([36., 30., 35., 38., 20., 25., 33., 28., 22., 32., 34., 39., 26.,
#        21., 27., 31., 37., 29., 23., 24., 50., 15.])

# %%
d.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.heatmap(np.round(df.select_dtypes(exclude='object').corr(),2),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings',
#        'Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Order_Date', 'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)', 'Distance in kms'],
#       dtype='object')

# %%
df.columns[3:7]
# Out:
# Index(['Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude'],
#       dtype='object')

# %%
df.drop(df.columns[3:7],axis=1,inplace=True)

# %%
df
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0          DEHRES17DEL01                 36.0                      4.2
# 1          KOCRES16DEL01                 21.0                      4.7
# 2         PUNERES13DEL03                 23.0                      4.7
# 3         LUDHRES15DEL02                 34.0                      4.3
# 4          KNPRES14DEL02                 24.0                      4.7
# ...                  ...                  ...                      ...
# 45579      JAPRES04DEL01                 30.0                      4.8
# 45580      AGRRES16DEL01                 21.0                      4.6
# 45581     CHENRES08DEL03                 30.0                      4.9
# 45582    COIMBRES11DEL01                 20.0                      4.7
# 45583   RANCHIRES09DEL02                 23.0                      4.9
#
#        Order_Date Time_Orderd Time_Order_picked Weather_conditions  \
# ...

# %%
sns.heatmap(np.round(df.select_dtypes(exclude='object').corr(),2),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Order_Date Time_Orderd Time_Order_picked Weather_conditions  \
# 0  12-02-2022       21:55             22:10                Fog
# 1  13-02-2022       14:55             15:05             Stormy
# 2  04-03-2022       17:30             17:40         Sandstorms
# 3  13-02-2022       09:20             09:30         Sandstorms
# 4  14-02-2022       19:50             20:05                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
# ...

# %% [markdown]
# # Handling DateTime

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'],format='%d-%m-%Y')

# %%
df['Order_Day']=df['Order_Date'].dt.day
df['Order_month']=df['Order_Date'].dt.month
df['Order_year']=df['Order_Date'].dt.year

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings Order_Date  \
# 0      DEHRES17DEL01                 36.0                      4.2 2022-02-12
# 1      KOCRES16DEL01                 21.0                      4.7 2022-02-13
# 2     PUNERES13DEL03                 23.0                      4.7 2022-03-04
# 3     LUDHRES15DEL02                 34.0                      4.3 2022-02-13
# 4      KNPRES14DEL02                 24.0                      4.7 2022-02-14
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
# ...

# %% [markdown]
# # RUN

# %%
df.drop(['Order_Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
for i in df['Time_Orderd']:
    try:
        if type(i)==np.nan :
            print('Annaya Nan ochindhi')
        elif i.startswith('0.'):
            print(i)
        else:
            pass
    except AttributeError as e:
        print(e)
        continue
# Out:
# 0.458333333
# 0.958333333
# 'float' object has no attribute 'startswith'
# 0.791666667
# 'float' object has no attribute 'startswith'
# 0.875
# 0.958333333
# 'float' object has no attribute 'startswith'
# 0.375
# 'float' object has no attribute 'startswith'
# 0.791666667
# 'float' object has no attribute 'startswith'
# 0.958333333
# 0.625
# 0.375
# 0.833333333
# 0.666666667
# 0.791666667
# 0.75
# 'float' object has no attribute 'startswith'
# 0.458333333
# 0.458333333
# 0.875
# 'float' object has no attribute 'startswith'
# 0.416666667
# 'float' object has no attribute 'startswith'
# 0.916666667
# 'float' object has no attribute 'startswith'
# 0.958333333
# 0.75
# 0.791666667
# 0.375
# 'float' object has no attribute 'startswith'
# 0.458333333
# 0.666666667
# 'float' object has no attribute 'startswith'
# 'float' object has no attribute 'startswith'
# 0.875
# 0.791666667
# 0.75
# 'float' object has no attribute 'startswith'
# 'float' object has no attribute 'startswith'
# ...

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
for i in range(len(df['Time_Orderd'])):
    try:
        if df['Time_Orderd'][i].startswith('0.'):
            print(df['Time_Orderd'][i],df['Time_Order_picked'][i])
    except AttributeError as e:
        continue
# Out:
# 0.458333333 11:10
# 0.958333333 23:10
# 0.791666667 19:15
# 0.875 21:15
# 0.958333333 23:05
# 0.375 09:05
# 0.791666667 19:05
# 0.958333333 23:15
# 0.625 15:10
# 0.375 09:10
# 0.833333333 20:05
# 0.666666667 16:15
# 0.791666667 19:15
# 0.75 18:15
# 0.458333333 11:10
# 0.458333333 11:15
# 0.875 21:10
# 0.416666667 10:05
# 0.916666667 22:10
# 0.958333333 23:05
# 0.75 18:10
# 0.791666667 19:10
# 0.375 09:10
# 0.458333333 11:05
# 0.666666667 16:05
# 0.875 21:05
# 0.791666667 19:15
# 0.75 18:05
# 0.791666667 19:15
# 0.833333333 20:10
# 0.416666667 10:05
# 0.875 21:10
# 0.916666667 22:10
# 0.875 21:05
# 0.625 15:05
# 0.75 18:15
# 0.791666667 19:10
# 0.791666667 19:10
# 0.5 12:15
# 0.458333333 11:10
# 0.958333333 23:15
# 0.75 18:15
# 0.5 12:10
# 0.875 21:15
# 0.791666667 19:05
# 0.791666667 19:15
# 0.416666667 10:15
# 0.5 12:15
# 0.875 21:10
# 0.708333333 17:05
# 0.416666667 10:10
# 0.958333333 23:10
# 0.458333333 11:05
# 0.375 09:15
# 0.833333333 20:15
# 0.916666667 22:15
# ...

# %%
## Time difference function

# %% [markdown]
# # Checking the Time difference between Time orderd and Time_Order_picked

# %%
def sub_15_minutes(time_str):
    # Convert the time string to a datetime object
    time = pd.to_datetime(time_str, format='%H:%M')
    # Add 15 minutes
    num=np.random.choice([5,10,15])
    new_time = time - pd.Timedelta(minutes=num)
    # Convert back to time string
    return new_time.strftime('%H:%M')

# %%
k=[]
for i in range(len(df['Time_Orderd'])):
    #print(str(df['Time_Orderd'][i]),str(df['Time_Order_picked'][i]))
    try:
        if df['Time_Order_picked'][i].startswith('24'):
            print(df['Time_Order_picked'][i],df['Time_Order_picked'][i][3:6])
        else:
            if df['Time_Orderd'][i].startswith('0.'):
                #print(df['Time_Orderd'][i],df['Time_Order_picked'][i])
                #print(add_15_minutes(df['Time_Order_picked'][i]))
                k.append(str(sub_15_minutes(df['Time_Order_picked'][i][:6])))
            
            elif df['Time_Orderd'][i]=='1':
                k.append(str(sub_15_minutes(df['Time_Order_picked'][i][:6])))
            else:
                k.append(df['Time_Orderd'][i])
    except AttributeError as e:
        k.append(np.nan)
        print(np.nan)
# Out:
# nan
# nan
# 24:05:00 05:
# 24:10:00 10:
# nan
# 24:15:00 15:
# nan
# nan
# nan
# nan
# nan
# nan
# 24:10:00 10:
# nan
# 24:05:00 05:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 24:05:00 05:
# 24:05:00 05:
# nan
# nan
# nan
# 24:10:00 10:
# nan
# nan
# nan
# nan
# 24:05:00 05:
# 24:10:00 10:
# 24:05:00 05:
# nan
# nan
# nan
# nan
# 24:05:00 05:
# 24:15:00 15:
# nan
# nan
# 24:10:00 10:
# nan
# 24:15:00 15:
# nan
# nan
# nan
# 24:15:00 15:
# nan
# nan
# 24:05:00 05:
# nan
# 24:15:00 15:
# 24:05:00 05:
# 24:05:00 05:
# 24:10:00 10:
# nan
# nan
# nan
# nan
# nan
# 24:05:00 05:
# nan
# 24:05:00 05:
# 24:10:00 10:
# nan
# nan
# 24:05:00 05:
# 24:10:00 10:
# 24:05:00 05:
# nan
# nan
# nan
# nan
# 24:10:00 10:
# nan
# 24:15:00 15:
# nan
# 24:05:00 05:
# nan
# 24:10:00 10:
# nan
# nan
# 24:05:00 05:
# nan
# nan
# 24:05:00 05:
# nan
# nan
# nan
# 24:05:00 05:
# 24:10:00 10:
# 24:10:00 10:
# nan
# nan
# 24:10:00 10:
# 24:05:00 05:
# nan
# nan
# 24:10:00 10:
# nan
# nan
# ...

# %% [markdown]
# # RUN

# %% [markdown]
# # Major change

# %% [markdown]
# # Cleaning

# %%
df1=df.copy()

# %%
df1['Time_Order_picked']=df1['Time_Order_picked'].replace({'24:10:00':'00:10','24:15:00':'00:15','24:05:00':'00:05'})

# %%
k=[]
for i in range(len(df1['Time_Orderd'])):
    #print(str(df['Time_Orderd'][i]),str(df['Time_Order_picked'][i]))
    try:
        if df1['Time_Orderd'][i].startswith('0.'):
            #print(df['Time_Orderd'][i],df['Time_Order_picked'][i])
            #print(add_15_minutes(df['Time_Order_picked'][i]))
            k.append(str(sub_15_minutes(df1['Time_Order_picked'][i])))
        
        elif df1['Time_Orderd'][i]=='1':
            k.append(str(sub_15_minutes(df1['Time_Order_picked'][i])))
        else:
            k.append(df1['Time_Orderd'][i])
    except AttributeError as e:
        k.append(np.nan)
        #print(np.nan)

# %%
df1.sample(5)
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 33193      JAPRES11DEL01                 20.0                      4.7
# 45156      MYSRES15DEL01                 39.0                      4.7
# 1890    RANCHIRES11DEL01                 36.0                      4.9
# 21103      JAPRES19DEL02                 33.0                      4.8
# 45474     INDORES02DEL02                 25.0                      4.0
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 33193       18:55             19:05              Sunny               Medium
# 45156       11:20             11:35              Sunny                 High
# 1890        11:15             11:25             Cloudy                 High
# 21103       17:30             17:35             Stormy               Medium
# 45474       08:50             0.375             Stormy                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
pd.Series(k).value_counts()
# Out:
# 21:55    614
# 19:55    595
# 17:55    583
# 19:50    574
# 20:50    566
#         ...
# 15:00     29
# 17:00     27
# 13:00     26
# 14:00     23
# 16:00     20
# Name: count, Length: 175, dtype: int64

# %%
pd.Series(k).isna().sum()
# Out:
# 2161

# %%
len(k)
# Out:
# 45584

# %%
pd.Series(k).isna().sum()
# Out:
# 2161

# %%
df['Time_Orderd'].isna().sum()
# Out:
# 1731

# %%
df1['Time_Orderd'].isna().sum()
# Out:
# 2161

# %% [markdown]
# # RUN

# %%
df1['Time_Orderd']=k

# %%
df['Time_Orderd'].isna().sum()
# Out:
# 1731

# %%
df1['Time_Orderd'].isna().sum()
# Out:
# 2161

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Order_Date Time_Orderd Time_Order_picked Weather_conditions  \
# 0  12-02-2022       21:55             22:10                Fog
# 1  13-02-2022       14:55             15:05             Stormy
# 2  04-03-2022       17:30             17:40         Sandstorms
# 3  13-02-2022       09:20             09:30         Sandstorms
# 4  14-02-2022       19:50             20:05                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
# ...

# %%
df1[df1['Time_Order_picked']=='00:10']
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 92         HYDRES19DEL03                 25.0                      4.8
# 316        HYDRES05DEL03                 32.0                      4.9
# 599        BHPRES15DEL03                 38.0                      4.8
# 712       ALHRES010DEL02                 27.0                      5.0
# 886       AURGRES19DEL02                 25.0                      4.7
# ...                  ...                  ...                      ...
# 44005     AURGRES07DEL02                  NaN                      NaN
# 44061      ALHRES17DEL02                 26.0                      4.9
# 44839      KOLRES19DEL02                 28.0                      4.8
# 44922      MYSRES16DEL02                 36.0                      5.0
# 45522      VADRES17DEL02                 32.0                      4.8
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# ...

# %%
df1['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25',
#        '0.458333333', '19:15', '16:55', '11:40', '15:15', '22:55',
#        '22:25', '20:55', '23:05', '0.75', '0.958333333', '09:40', '20:20',
#        '22:35', '0.916666667', '23:55', '15:40', '10:30', '0.875',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '00:05', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '00:10', '10:40', '0.375', '20:45', '0.833333333',
#        '23:15', '22:20', '21:05', '0.708333333', '00:15', '21:20',
#        '14:35', '10:25', '09:05', '16:50', '08:40', '23:40', '21:50',
# ...

# %%
df1[df1['Time_Orderd']=='10:55']
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 36         KOLRES16DEL02                 37.0                      4.9
# 99         SURRES09DEL02                 27.0                      4.7
# 211        KOCRES03DEL01                 25.0                      5.0
# 639       INDORES08DEL01                 32.0                      4.0
# 687       PUNERES02DEL01                 24.0                      4.8
# ...                  ...                  ...                      ...
# 44705      JAPRES19DEL02                 22.0                      4.8
# 44870   RANCHIRES03DEL01                 21.0                      4.7
# 44923      VADRES02DEL02                 32.0                      4.8
# 45272      ALHRES13DEL02                 28.0                      4.9
# 45419      BHPRES12DEL02                 25.0                      4.7
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# ...

# %%
df1['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '10:55', '09:45', '08:40',
#        '22:55', '17:25', nan, '19:45', '19:10', '21:40', '19:00', '16:45',
#        '11:30', '15:10', '22:45', '22:10', '20:45', '22:50', '17:55',
#        '09:25', '20:15', '22:25', '22:40', '23:50', '15:25', '10:20',
#        '20:55', '10:40', '15:55', '20:10', '12:10', '15:30', '10:35',
#        '21:10', '20:50', '12:35', '21:00', '23:40', '18:15', '18:20',
#        '11:45', '12:45', '23:30', '10:50', '21:25', '10:10', '17:50',
#        '22:20', '12:40', '23:55', '10:25', '08:45', '23:45', '19:55',
#        '22:15', '23:10', '09:15', '18:25', '18:45', '16:50', '00:00',
#        '14:20', '10:15', '08:50', '17:45', '16:35', '08:30', '21:45',
# ...

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %% [markdown]
# # Major change

# %% [markdown]
# # RUN

# %%
np.random.choice([5,10,15])
# Out:
# 15

# %%
def add_15_minutes(time_str):
    # Convert the time string to a datetime object
    time = pd.to_datetime(time_str, format='%H:%M')
    # Add 15 minutes
    num=np.random.choice([5,10,15])
    new_time = time + pd.Timedelta(minutes=num)
    # Convert back to time string
    return new_time.strftime('%H:%M')

# %%
k=[]
for i in range(len(df1['Time_Order_picked'])):
    #print(str(df['Time_Orderd'][i]),str(df['Time_Order_picked'][i]))
    try:
        if df1['Time_Order_picked'][i].startswith('0.'):
            print(df['Time_Orderd'][i],df['Time_Order_picked'][i])
            print(add_15_minutes(df['Time_Orderd'][i]))
            k.append(str(add_15_minutes(df1['Time_Orderd'][i])))
        
        elif df1['Time_Order_picked'][i]=='1':
            k.append(str(add_15_minutes(df1['Time_Orderd'][i])))
        else:
            k.append(df1['Time_Order_picked'][i])
    except Exception as e:
        k.append(np.nan)
        #print(np.nan)
# Out:
# 10:55 0.458333333
# 11:00
# 17:55 0.75
# 18:00
# 22:45 0.958333333
# 22:55
# 21:55 0.916666667
# 22:05
# 20:55 0.875
# 21:00
# 20:50 0.875
# 21:00
# 22:50 0.958333333
# 23:00
# 08:45 0.375
# 08:55
# 19:55 0.833333333
# 20:10
# 16:50 0.708333333
# 17:05
# 17:45 0.75
# 17:55
# 14:50 0.625
# 15:05
# 17:50 0.75
# 18:00
# 18:45 0.791666667
# 19:00
# 08:50 0.375
# 09:00
# 16:55 0.708333333
# 17:00
# 22:55 0.958333333
# 23:05
# 10:55 0.458333333
# 11:00
# 22:45 0.958333333
# 22:50
# 18:55 0.791666667
# 19:00
# 17:55 0.75
# 18:00
# 11:50 0.5
# 12:00
# 19:45 0.833333333
# 19:50
# 11:45 0.5
# 11:50
# 21:45 0.916666667
# 21:55
# 17:45 0.75
# 17:50
# 22:50 0.958333333
# 22:55
# nan 0.541666667
# 20:45 0.875
# 20:55
# 17:50 0.75
# 18:00
# 21:45 0.916666667
# 21:55
# 11:45 0.5
# 11:50
# 11:55 0.5
# 12:10
# 19:50 0.833333333
# 20:00
# 21:50 0.916666667
# 22:05
# 09:50 0.416666667
# 09:55
# 18:55 0.791666667
# 19:10
# 17:45 0.75
# 18:00
# 19:45 0.833333333
# 20:00
# 19:55 0.833333333
# 20:05
# ...

# %%
df1['Time_Order_picked'].value_counts()
# Out:
# Time_Order_picked
# 21:30    495
# 22:50    474
# 22:40    458
# 18:40    457
# 17:55    456
#         ...
# 08:15     48
# 16:15     46
# 16:10     43
# 17:10     39
# 16:20     38
# Name: count, Length: 193, dtype: int64

# %%
pd.Series(k).isna().sum()
# Out:
# 160

# %%
df1
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0          DEHRES17DEL01                 36.0                      4.2
# 1          KOCRES16DEL01                 21.0                      4.7
# 2         PUNERES13DEL03                 23.0                      4.7
# 3         LUDHRES15DEL02                 34.0                      4.3
# 4          KNPRES14DEL02                 24.0                      4.7
# ...                  ...                  ...                      ...
# 45579      JAPRES04DEL01                 30.0                      4.8
# 45580      AGRRES16DEL01                 21.0                      4.6
# 45581     CHENRES08DEL03                 30.0                      4.9
# 45582    COIMBRES11DEL01                 20.0                      4.7
# 45583   RANCHIRES09DEL02                 23.0                      4.9
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# ...

# %%
df['Time_Order_picked'].isna().sum()
# Out:
# 0

# %%
df[df['Time_Order_picked']=='0.458333333']
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 36         KOLRES16DEL02                 37.0                      4.9
# 211        KOCRES03DEL01                 25.0                      5.0
# 639       INDORES08DEL01                 32.0                      4.0
# 871        SURRES02DEL01                 27.0                      4.6
# 874       CHENRES18DEL02                 35.0                      4.5
# ...                  ...                  ...                      ...
# 43782      SURRES01DEL02                 22.0                      4.7
# 43850    COIMBRES06DEL02                 24.0                      4.8
# 44072    COIMBRES06DEL01                 29.0                      4.5
# 44653      MUMRES05DEL02                 21.0                      4.2
# 45538      GOARES20DEL02                 37.0                      4.3
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# ...

# %%
df1[df1['Time_Order_picked']=='0.458333333']
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 36         KOLRES16DEL02                 37.0                      4.9
# 211        KOCRES03DEL01                 25.0                      5.0
# 639       INDORES08DEL01                 32.0                      4.0
# 871        SURRES02DEL01                 27.0                      4.6
# 874       CHENRES18DEL02                 35.0                      4.5
# ...                  ...                  ...                      ...
# 43782      SURRES01DEL02                 22.0                      4.7
# 43850    COIMBRES06DEL02                 24.0                      4.8
# 44072    COIMBRES06DEL01                 29.0                      4.5
# 44653      MUMRES05DEL02                 21.0                      4.2
# 45538      GOARES20DEL02                 37.0                      4.3
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# ...

# %%
k[44653]
# Out:
# '11:05'

# %%
df[(df['Time_Orderd'].isna()) & (df['Time_Order_picked']=='0.458333333')]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 4796    RANCHIRES02DEL02                  NaN                      NaN
# 23969    COIMBRES16DEL02                  NaN                      NaN
# 43199      MYSRES01DEL01                  NaN                      NaN
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 4796          NaN       0.458333333             Cloudy                  Low
# 23969         NaN       0.458333333              Sunny                  Low
# 43199         NaN       0.458333333             Cloudy                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 4796                   1          Meal      motorcycle                  0.0
# 23969                  2         Snack         scooter                  1.0
# 43199                  2          Meal         scooter                  0.0
#
# ...

# %%
pd.Series(k).isna().sum()
# Out:
# 160

# %%
df1['Time_Order_picked']=k

# %%
df1[23969:23969+1]
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 23969    COIMBRES16DEL02                  NaN                      NaN
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 23969         NaN               NaN              Sunny                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 23969                  2         Snack         scooter                  1.0
#
#       Festival   City  Time_taken (min)  Distance in kms  Order_Day  \
# 23969       No  Urban                19              3.1          1
#
#        Order_month  Order_year
# 23969            3        2022

# %%
df1['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25', '11:00',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '18:05', '09:40', '20:20', '22:35', '22:05', '23:55',
#        '15:40', '10:30', '21:00', '10:50', '16:05', '20:15', '12:15',
#        '15:45', '22:15', '10:45', '15:30', '00:05', '21:25', '12:45',
#        '21:15', '18:20', '18:25', '11:50', '12:50', '10:55', '21:40',
#        '10:20', '17:55', '23:50', '12:55', '00:10', '23:00', '10:40',
#        '08:50', '20:45', '23:15', '22:20', '21:05', '00:15', '21:20',
#        '14:35', '10:25', '09:05', '16:50', '08:40', '23:40', '21:50',
# ...

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
pd.to_datetime(df1['Time_Order_picked'],format='%H:%M')
# Out:
# 0       1900-01-01 22:10:00
# 1       1900-01-01 15:05:00
# 2       1900-01-01 17:40:00
# 3       1900-01-01 09:30:00
# 4       1900-01-01 20:05:00
#                 ...
# 45579   1900-01-01 11:45:00
# 45580   1900-01-01 20:10:00
# 45581   1900-01-01 00:05:00
# 45582   1900-01-01 13:40:00
# 45583   1900-01-01 17:15:00
# Name: Time_Order_picked, Length: 45584, dtype: datetime64[ns]

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %% [markdown]
# ## RUN

# %%
#Time_Orderd
k=[]#hour
l=[]#min
for i in df1['Time_Orderd']:
    if type(i)==str:
        k.append(int(i[:2]))
        l.append(int(i[3:5]))
    else:
        k.append(np.nan)
        l.append(np.nan)

# %%
pd.Series(l).unique()
# Out:
# array([55., 30., 20., 50., 25., 40., 15., 35.,  5., 45.,  0., nan, 10.])

# %%
pd.Series(l).unique()

# %%
df1['Time_Orderd_Hour']=k
df1['Time_Orderd_mins']=l

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
#Time_Orderd
k=[]#hour
l=[]#min
for i in df1['Time_Order_picked']:
    if type(i)==str:
        k.append(int(i[:2]))
        l.append(int(i[3:5]))
    else:
        k.append(np.nan)
        l.append(np.nan)

# %%
df1['Time_Order_picked_Hour']=k
df1['Time_Order_picked_mins']=l

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 0       21:55             22:10                Fog                  Jam
# 1       14:55             15:05             Stormy                 High
# 2       17:30             17:40         Sandstorms               Medium
# 3       09:20             09:30         Sandstorms                  Low
# 4       19:50             20:05                Fog                  Jam
#
#    Vehicle_condition Type_of_order Type_of_vehicle  ...           City  \
# ...

# %%
df1.sample(5)
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 4804       KOCRES07DEL01                 23.0                      5.0
# 23210      KOLRES01DEL01                 31.0                      4.8
# 4055       MUMRES19DEL01                 38.0                      4.3
# 19418      JAPRES03DEL02                 25.0                      4.8
# 25895      MUMRES04DEL02                 23.0                      4.9
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 4804        23:50             00:05         Sandstorms                  Low
# 23210       10:15             10:20             Cloudy                  Low
# 4055        16:40             16:50              Windy               Medium
# 19418       18:25             18:40         Sandstorms               Medium
# 25895       17:40             17:55             Cloudy               Medium
#
#        Vehicle_condition Type_of_order Type_of_vehicle  ...           City  \
# ...

# %%
df1.drop(['Time_Orderd','Time_Order_picked'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
df.to_csv('Data/Semi_Cleaned_data.csv')

# %%
df1.to_csv('Data/Semi_Cleaned_data.csv')

# %%
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
df.isna().sum()
# Out:
# Delivery_person_ID            0
# Delivery_person_Age        1854
# Delivery_person_Ratings    1908
# Time_Orderd                1731
# Time_Order_picked             0
# Weather_conditions          616
# Road_traffic_density        601
# Vehicle_condition             0
# Type_of_order                 0
# Type_of_vehicle               0
# multiple_deliveries         993
# Festival                    228
# City                       1200
# Time_taken (min)              0
# Distance in kms               0
# Order_Day                     0
# Order_month                   0
# Order_year                    0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Delivery_person_ID            0
# Delivery_person_Age        1854
# Delivery_person_Ratings    1908
# Weather_conditions          616
# Road_traffic_density        601
# Vehicle_condition             0
# Type_of_order                 0
# Type_of_vehicle               0
# multiple_deliveries         993
# Festival                    228
# City                       1200
# Time_taken (min)              0
# Distance in kms               0
# Order_Day                     0
# Order_month                   0
# Order_year                    0
# Time_Orderd_Hour           1731
# Time_Orderd_mins           1731
# Time_Order_picked_Hour      160
# Time_Order_picked_mins      160
# dtype: int64
