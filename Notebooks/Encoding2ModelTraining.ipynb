# %% [markdown]
# ## Dataset Location : 'c:\\Users\\new\\OneDrive\\Desktop\\Zomato project\\Notebooks\\Data'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Data/Semi_Cleaned_data.csv')

# %%
df.drop([df.columns[0]],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %% [markdown]
# # Encoding

# %% [markdown]
# Delivery_person_ID,Weather_conditions,Road_traffic_density,Type_of_order,Type_of_vehicle,Festival,City : nominal
# ['Road_traffic_density','Type_of_vehicle'] :Ordinal

# %% [markdown]
# ### Ordinal encoding

# %%
k=[]
l=[]
for i in df['Road_traffic_density']:
    if type(i)==float:
        k.append(np.nan)
    elif i=='Low':
            k.append(0)
    elif i=='Medium':
        k.append(1)
    elif i=='High':
        k.append(2)
    elif i=='Jam':
        k.append(3)
    else:
        pass

# %%
df['Type_of_vehicle']=df['Type_of_vehicle'].replace({'bicycle':0,'scooter':1,'motorcycle':2,'electric_scooter':3})

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
df['Road_traffic_density']=pd.Series(k)

# %%
df.columns
# Out:
# Index(['Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings',
#        'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City', 'Time_taken (min)', 'Distance in kms', 'Order_Day',
#        'Order_month', 'Order_year', 'Time_Orderd_Hour', 'Time_Orderd_mins',
#        'Time_Order_picked_Hour', 'Time_Order_picked_mins'],
#       dtype='object')

# %%
#Train test split
X=df.drop(['Time_taken (min)'],axis=1)
y=df[['Time_taken (min)']]

# %%
X.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions  Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                   3.0                  2         Snack
# 1             Stormy                   2.0                  1          Meal
# 2         Sandstorms                   1.0                  1        Drinks
# 3         Sandstorms                   0.0                  0        Buffet
# 4                Fog                   3.0                  1         Snack
#
#    Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((31908, 19), (13676, 19))

# %%
y_train.shape,y_test.shape
# Out:
# ((31908, 1), (13676, 1))

# %%
transformer=ColumnTransformer(transformers=[
    ("tnf1",OneHotEncoder(drop='first',sparse_output=False,),['Delivery_person_ID','Weather_conditions','Type_of_order','Festival','City'])
    ],remainder="passthrough")

# %%
X_train_va=transformer.fit_transform(X_train)
X_test_va=transformer.transform(X_test)

# %%
X_train_va.shape
# Out:
# (31908, 1347)

# %%
X_test_va.shape
# Out:
# (13676, 1347)

# %%
pd.get_dummies(X_train,drop_first=True).shape
# Out:
# (31908, 1344)

# %%
k=0
for i in df.select_dtypes(include='object').columns:
    k+=len(df[i].unique())
    print(df[i].unique(),len(df[i].unique()),k)
# Out:
# ['DEHRES17DEL01' 'KOCRES16DEL01' 'PUNERES13DEL03' ... 'KOCRES04DEL01'
#  'BHPRES06DEL03' 'GOARES03DEL03'] 1320 1320
# ['Fog' 'Stormy' 'Sandstorms' 'Windy' 'Cloudy' 'Sunny' nan] 7 1327
# ['Snack' 'Meal' 'Drinks' 'Buffet'] 4 1331
# ['No' 'Yes' nan] 3 1334
# ['Metropolitian' 'Urban' 'Semi-Urban' nan] 4 1338

# %%
k
# Out:
# 1338

# %%
1338+11
# Out:
# 1349

# %%
df.isna().sum()
# Out:
# Delivery_person_ID            0
# Delivery_person_Age        1854
# Delivery_person_Ratings    1908
# Weather_conditions          616
# Road_traffic_density        601
# Vehicle_condition             0
# Type_of_order                 0
# Type_of_vehicle               0
# multiple_deliveries         993
# Festival                    228
# City                       1200
# Time_taken (min)              0
# Distance in kms               0
# Order_Day                     0
# Order_month                   0
# Order_year                    0
# Time_Orderd_Hour           1731
# Time_Orderd_mins           1731
# Time_Order_picked_Hour      160
# Time_Order_picked_mins      160
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_ID       45584 non-null  object
#  1   Delivery_person_Age      43730 non-null  float64
#  2   Delivery_person_Ratings  43676 non-null  float64
#  3   Weather_conditions       44968 non-null  object
#  4   Road_traffic_density     44983 non-null  float64
#  5   Vehicle_condition        45584 non-null  int64
#  6   Type_of_order            45584 non-null  object
#  7   Type_of_vehicle          45584 non-null  int64
#  8   multiple_deliveries      44591 non-null  float64
#  9   Festival                 45356 non-null  object
#  10  City                     44384 non-null  object
#  11  Time_taken (min)         45584 non-null  int64
#  12  Distance in kms          45584 non-null  float64
#  13  Order_Day                45584 non-null  int64
# ...

# %%
pd.get_dummies(X_train,drop_first=True).columns[1320:]
# Out:
# Index(['Delivery_person_ID_VADRES16DEL03', 'Delivery_person_ID_VADRES17DEL01',
#        'Delivery_person_ID_VADRES17DEL02', 'Delivery_person_ID_VADRES17DEL03',
#        'Delivery_person_ID_VADRES18DEL01', 'Delivery_person_ID_VADRES18DEL02',
#        'Delivery_person_ID_VADRES18DEL03', 'Delivery_person_ID_VADRES19DEL01',
#        'Delivery_person_ID_VADRES19DEL02', 'Delivery_person_ID_VADRES19DEL03',
#        'Delivery_person_ID_VADRES20DEL01', 'Delivery_person_ID_VADRES20DEL02',
#        'Delivery_person_ID_VADRES20DEL03', 'Weather_conditions_Fog',
#        'Weather_conditions_Sandstorms', 'Weather_conditions_Stormy',
#        'Weather_conditions_Sunny', 'Weather_conditions_Windy',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes', 'City_Semi-Urban', 'City_Urban'],
#       dtype='object')

# %% [markdown]
# # Iterative Imputer

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer  # noqa
 # now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer  # noqa
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer
from sklearn.svm import SVR,SVC

# %%
I=IterativeImputer()

# %%
X_train_va[100][1330:]
# Out:
# array([   0. ,    0. ,    0. ,    nan,    nan,    nan,    3. ,    3. ,
#           0. ,    6.3,   13. ,    3. , 2022. ,    nan,    nan,   12. ,
#          40. ])

# %%
X_tr=I.fit_transform(X_train_va)
X_te=I.transform(X_test_va)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 X_tr=I.fit_transform(X_train_va)
#       2 X_te=I.transform(X_test_va)
#
# File c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# ...

# %%
X_tr[0]
# Out:
# array([3.500e+01, 4.600e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.100e+01,
#        2.000e+01, 3.000e+00, 2.022e+03, 1.700e+01, 1.500e+01, 1.700e+01,
#        3.000e+01])

# %%
X_train['Delivery_person_ID']
# Out:
# 32032    RANCHIRES12DEL01
# 1953     RANCHIRES13DEL01
# 5729        HYDRES07DEL02
# 41624      INDORES01DEL01
# 40690       KOLRES20DEL03
#                ...
# 11284       VADRES09DEL02
# 44732       SURRES07DEL03
# 38158      PUNERES03DEL02
# 860         MUMRES20DEL01
# 15795      CHENRES04DEL02
# Name: Delivery_person_ID, Length: 31908, dtype: object

# %% [markdown]
# # Excluding ID column

# %%
#Train test split
X=df.drop(['Time_taken (min)'],axis=1)
y=df[['Time_taken (min)']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
transformer=ColumnTransformer(transformers=[
    ("tnf1",OneHotEncoder(drop='first',sparse_output=False,),['Delivery_person_ID','Weather_conditions','Type_of_order','Festival','City'])
    ],remainder="passthrough")

# %%
X_train_va=transformer.fit_transform(X_train)
X_test_va=transformer.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train_sc=sc.fit_transform(X_train_va)
X_test_sc=sc.transform(X_test_va)

# %%
X_test_sc

# %%
X_train_va[5]
# Out:
# array([ 0.,  0.,  0., ..., 35.,  8., 40.])

# %%
X_tr=I.fit_transform(X_train_sc)
X_te=I.transform(X_test_sc)

# %%
X_tr
# Out:
# array([[ 0.,  0.,  0., ..., 15., 17., 30.],
#        [ 0.,  1.,  0., ..., 30., 13., 40.],
#        [ 0.,  0.,  1., ..., 35., 22., 40.],
#        ...,
#        [ 0.,  0.,  0., ..., 25., 22., 35.],
#        [ 0.,  0.,  1., ..., 30., 17., 35.],
#        [ 0.,  0.,  1., ..., 20., 19., 35.]])

# %%
X_train.head()
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 32032   RANCHIRES12DEL01                 35.0                      4.6
# 1953    RANCHIRES13DEL01                 38.0                      4.7
# 5729       HYDRES07DEL02                 36.0                      4.8
# 41624     INDORES01DEL01                 27.0                      5.0
# 40690      KOLRES20DEL03                 38.0                      4.7
#
#       Weather_conditions  Road_traffic_density  Vehicle_condition  \
# 32032              Windy                   1.0                  1
# 1953          Sandstorms                   2.0                  2
# 5729              Stormy                   0.0                  2
# 41624             Stormy                   1.0                  2
# 40690             Cloudy                   3.0                  0
#
#       Type_of_order  Type_of_vehicle  multiple_deliveries Festival  \
# 32032        Drinks                1                  1.0       No
# ...

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions  Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                   3.0                  2         Snack
# 1             Stormy                   2.0                  1          Meal
# 2         Sandstorms                   1.0                  1        Drinks
# 3         Sandstorms                   0.0                  0        Buffet
# 4                Fog                   3.0                  1         Snack
#
#    Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
df.groupby(['Delivery_person_ID'])['Time_taken (min)'].agg(['mean', 'count']).sort_values(by='count',ascending=False).reset_index()
# Out:
#      Delivery_person_ID       mean  count
# 0         JAPRES11DEL02  28.597015     67
# 1        PUNERES01DEL01  27.925373     67
# 2      RANCHIRES02DEL01  26.924242     66
# 3         VADRES11DEL02  29.242424     66
# 4         HYDRES04DEL02  27.151515     66
# ...                 ...        ...    ...
# 1315      BHPRES15DEL03  20.142857      7
# 1316      GOARES01DEL03  26.142857      7
# 1317      KOLRES09DEL03  31.500000      6
# 1318      KOCRES16DEL03  21.000000      6
# 1319     BHPRES010DEL03  30.000000      5
#
# [1320 rows x 3 columns]

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions  Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                   3.0                  2         Snack
# 1             Stormy                   2.0                  1          Meal
# 2         Sandstorms                   1.0                  1        Drinks
# 3         Sandstorms                   0.0                  0        Buffet
# 4                Fog                   3.0                  1         Snack
#
#    Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
X_train_va.shape
# Out:
# (31908, 1347)

# %% [markdown]
# # Including ID column

# %% [markdown]
# ## KNN imputer

# %%
from sklearn.impute import KNNImputer
knn=KNNImputer()

# %%
X_train_knn=knn.fit_transform(X_train_va)
X_test_knn=knn.transform(X_test_va)

# %%
X_train_knn
# Out:
# array([[ 0.,  0.,  0., ..., 15., 17., 30.],
#        [ 0.,  0.,  0., ..., 30., 13., 40.],
#        [ 0.,  0.,  0., ..., 35., 22., 40.],
#        ...,
#        [ 0.,  0.,  0., ..., 25., 22., 35.],
#        [ 0.,  0.,  0., ..., 30., 17., 35.],
#        [ 0.,  0.,  0., ..., 20., 19., 35.]])

# %%
X_train_knn[0]
# Out:
# array([ 0.,  0.,  0., ..., 15., 17., 30.])

# %%
from sklearn.linear_model import LinearRegression

# %%
## Linear Regression

# %%
Model1=LinearRegression()
Model2=LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train_scaled=sc.fit_transform(X_train_knn)
X_test_scaled=sc.transform(X_test_knn)

# %% [markdown]
# # Model on non-sclaed values

# %%
Model1.fit(X_train_knn,y_train)
y_pred_m1=Model1.predict(X_test_knn)

# %% [markdown]
# # Model on scaled values

# %%
Model2.fit(X_train_scaled,y_train)
y_pred_m2=Model2.predict(X_test_scaled)

# %% [markdown]
# # Accuracy scores

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred_m1)
# Out:
# 0.5427409841844921

# %%
r2_score(y_test,y_pred_m2)
# Out:
# 0.5427409841844872

# %%
from sklearn.svm import SVR

# %%
svr1=SVR()
svr2=SVR()

# %%
svr1.fit(X_train_va,y_train)
y_pred_svr1=svr1.predict(X_test_va)

# %%
r2_score(y_test,y_pred_svr1)
# Out:
# 0.40904246537103206

# %%
svr2.fit(X_train_va,y_train)
y_pred_svr2=svr2.predict(X_test_va)

# %% [markdown]
# # Using Frequency encoding on person Id column

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#   Weather_conditions  Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                   3.0                  2         Snack
# 1             Stormy                   2.0                  1          Meal
# 2         Sandstorms                   1.0                  1        Drinks
# 3         Sandstorms                   0.0                  0        Buffet
# 4                Fog                   3.0                  1         Snack
#
#    Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
temp=df['Delivery_person_ID'].value_counts().reset_index()
h={}
h=dict(h)

# %%
for i in range(len(temp['Delivery_person_ID'])):
    h[str(temp['Delivery_person_ID'][i])]=temp['count'][i]

# %%
temp
# Out:
#      Delivery_person_ID  count
# 0         JAPRES11DEL02     67
# 1        PUNERES01DEL01     67
# 2         VADRES11DEL02     66
# 3         VADRES08DEL02     66
# 4         JAPRES03DEL01     66
# ...                 ...    ...
# 1315      GOARES01DEL03      7
# 1316      DEHRES18DEL03      7
# 1317      KOCRES16DEL03      6
# 1318      KOLRES09DEL03      6
# 1319     BHPRES010DEL03      5
#
# [1320 rows x 2 columns]

# %%
for i,j in h.items():
    print(i,j)
# Out:
# JAPRES11DEL02 67
# PUNERES01DEL01 67
# VADRES11DEL02 66
# VADRES08DEL02 66
# JAPRES03DEL01 66
# RANCHIRES02DEL01 66
# HYDRES04DEL02 66
# VADRES14DEL01 65
# RANCHIRES02DEL02 65
# SURRES11DEL01 65
# JAPRES09DEL02 65
# INDORES08DEL02 65
# INDORES15DEL01 65
# VADRES11DEL01 65
# BANGRES03DEL01 65
# BANGRES07DEL02 65
# MUMRES14DEL02 64
# RANCHIRES16DEL01 64
# MUMRES02DEL02 64
# COIMBRES010DEL02 64
# VADRES12DEL02 64
# HYDRES12DEL02 64
# MUMRES01DEL01 63
# INDORES03DEL02 63
# BANGRES16DEL02 63
# SURRES01DEL02 63
# JAPRES14DEL02 63
# JAPRES17DEL01 63
# HYDRES11DEL02 63
# MYSRES14DEL01 63
# SURRES010DEL02 63
# PUNERES17DEL01 63
# COIMBRES02DEL01 63
# JAPRES20DEL02 63
# BANGRES09DEL01 63
# HYDRES08DEL02 63
# CHENRES12DEL02 63
# MYSRES05DEL01 63
# RANCHIRES14DEL02 63
# MYSRES04DEL02 63
# CHENRES16DEL02 63
# SURRES13DEL02 63
# MYSRES05DEL02 63
# HYDRES02DEL01 63
# JAPRES19DEL03 62
# MUMRES03DEL02 62
# HYDRES19DEL01 62
# BANGRES05DEL02 62
# MUMRES04DEL02 62
# COIMBRES11DEL01 62
# ...

# %%
df1=df.copy()

# %% [markdown]
# # Production

# %% [markdown]
# ## append the new record's to the dictionary and and add ID in dictionary and use replace() and then give it to model because model itself cant understand the agentID

# %%
df1['Delivery_person_ID']=df1['Delivery_person_ID'].replace(h)

# %%
df1.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0                  12                 36.0                      4.2
# 1                  13                 21.0                      4.7
# 2                  39                 23.0                      4.7
# 3                  15                 34.0                      4.3
# 4                  13                 24.0                      4.7
#
#   Weather_conditions  Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                   3.0                  2         Snack
# 1             Stormy                   2.0                  1          Meal
# 2         Sandstorms                   1.0                  1        Drinks
# 3         Sandstorms                   0.0                  0        Buffet
# 4                Fog                   3.0                  1         Snack
#
#    Type_of_vehicle  multiple_deliveries Festival           City  \
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(df1.drop(['Time_taken (min)'],axis=1),df1[['Time_taken (min)']],test_size=0.3,random_state=45)

# %%
transformer=ColumnTransformer(transformers=[
    ("tnf1",OneHotEncoder(drop='first',sparse_output=False,),['Weather_conditions','Type_of_order','Festival','City'])
    ],remainder="passthrough")
X_train_va=transformer.fit_transform(X_train)
X_test_va=transformer.transform(X_test)
X_train_sc=sc.fit_transform(X_train_va)
X_test_sc=sc.transform(X_test_va)
X_train_knn=knn.fit_transform(X_train_va)
X_test_knn=knn.transform(X_test_va)

# %%
X_train_knn_sc=knn.fit_transform(X_train_sc)
X_test_knn_sc=knn.transform(X_test_sc)

# %% [markdown]
# ## Model performance

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
m1=LinearRegression()
m2=SVR()

# %%
m1.fit(X_train_knn,y_train)
ypred1=m1.predict(X_test_knn)

# %%
m2.fit(X_train_knn_sc,y_train)
ypred2=m2.predict(X_test_knn_sc)
# Out:
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Scores

# %%
from sklearn.metrics import r2_score
print(f"M1 score : {r2_score(y_test,ypred1)}")
print(f"M2 score : {r2_score(y_test,ypred2)}")
# Out:
# M1 score : 0.5579820785530447
# M2 score : 0.6472896623814611

# %% [markdown]
# # XGBoost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# without knn sc

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error


# Convert the datasets into DMatrix objects, which are optimized for XGBoost
dtrain = xgb.DMatrix(X_train_sc, label=y_train)
dtest = xgb.DMatrix(X_test_sc, label=y_test)
# Set up the parameters for the XGBoost model
params = {
    'booster': 'gbtree',          # Type of model (gbtree, gblinear, or dart)
    'objective': 'reg:squarederror',  # Regression with squared loss
    'eta': 0.1,                   # Learning rate
    'max_depth': 6,               # Maximum depth of a tree
    'eval_metric': 'rmse'         # Evaluation metric during training
}

# Train the model
num_round = 100
bst = xgb.train(params, dtrain, num_round)

# Make predictions
preds = bst.predict(dtest)

# Evaluate the model using RMSE and R² score
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# RMSE: 4.05
# R² Score: 0.81

# %% [markdown]
# Using Knn_sc

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error


# Convert the datasets into DMatrix objects, which are optimized for XGBoost
dtrain = xgb.DMatrix(X_train_knn_sc, label=y_train)
dtest = xgb.DMatrix(X_test_knn_sc, label=y_test)
# Set up the parameters for the XGBoost model
params = {
    'booster': 'gbtree',          # Type of model (gbtree, gblinear, or dart)
    'objective': 'reg:squarederror',  # Regression with squared loss
    'eta': 0.1,                   # Learning rate
    'max_depth': 6,               # Maximum depth of a tree
    'eval_metric': 'rmse'         # Evaluation metric during training
}

# Train the model
num_round = 100
bst = xgb.train(params, dtrain, num_round)

# Make predictions
preds = bst.predict(dtest)

# Evaluate the model using RMSE and R² score
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# RMSE: 4.09
# R² Score: 0.81

# %% [markdown]
# # lightgbm

# %%
pip install lightgbm
# Out:
# ...
#   Obtaining dependency information for lightgbm from https://files.pythonhosted.org/packages/e1/4c/4685ccfae9806f561de716e32549190c1f533dde5bcadaf83bdf23972cf0/lightgbm-4.3.0-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.3 MB 660.6 kB/s eta 0:00:02
#    ------------- -------------------------- 0.4/1.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 9.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# with out knn sc

# %%
import lightgbm as lgb

from sklearn.metrics import mean_squared_error, r2_score


# Convert the datasets into LightGBM datasets
dtrain = lgb.Dataset(X_train_sc, label=y_train)
dtest = lgb.Dataset(X_test_sc, label=y_test, reference=dtrain)

# Specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# Train the model
gbm = lgb.train(
    params,
    dtrain,
    num_boost_round=1000,  # Increase num_boost_round and allow early stopping to take effect
    valid_sets=[dtest, dtrain],  # List of datasets for early stopping
    valid_names=['test', 'train'],  # Names of validation datasets
    #early_stopping_rounds=10,  # Early stopping rounds
    #verbose_eval=50  # Print evaluation results every 50 rounds
)

# Make predictions
preds = gbm.predict(X_test_sc, num_iteration=gbm.best_iteration)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 448
# [LightGBM] [Info] Number of data points in the train set: 31908, number of used features: 28
# [LightGBM] [Info] Start training from score 26.277924
# RMSE: 3.97
# R² Score: 0.82

# %% [markdown]
# with knn sc

# %%
import lightgbm as lgb

from sklearn.metrics import mean_squared_error, r2_score


# Convert the datasets into LightGBM datasets
dtrain = lgb.Dataset(X_train_knn_sc, label=y_train)
dtest = lgb.Dataset(X_test_knn_sc, label=y_test, reference=dtrain)

# Specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# Train the model
gbm = lgb.train(
    params,
    dtrain,
    num_boost_round=1000,  # Increase num_boost_round and allow early stopping to take effect
    valid_sets=[dtest, dtrain],  # List of datasets for early stopping
    valid_names=['test', 'train'],  # Names of validation datasets
    #early_stopping_rounds=10,  # Early stopping rounds
    #verbose_eval=50  # Print evaluation results every 50 rounds
)

# Make predictions
preds = gbm.predict(X_test_sc, num_iteration=gbm.best_iteration)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001449 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 807
# [LightGBM] [Info] Number of data points in the train set: 31908, number of used features: 28
# [LightGBM] [Info] Start training from score 26.277924
# RMSE: 3.95
# R² Score: 0.82

# %% [markdown]
# # Catboost

# %%
pip install catboost
# Out:
# ...
#   Obtaining dependency information for catboost from https://files.pythonhosted.org/packages/70/d5/ada4348d737c3aa0a4bb4d3fdb85f9084ac56671daa63087d7c0cafa9fbe/catboost-1.2.5-cp38-cp38-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/00/be/d59db2d1d52697c6adc9eacaf50e8965b6345cc143f671e1ed068818d5cf/graphviz-0.20.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/101.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.2 MB 640.0 kB/s eta 0:02:39
#    ---------------------------------------- 0.2/101.2 MB 1.8 MB/s eta 0:00:55
#    ---------------------------------------- 0.7/101.2 MB 5.2 MB/s eta 0:00:20
#     --------------------------------------- 2.1/101.2 MB 12.3 MB/s eta 0:00:09
#    - -------------------------------------- 4.5/101.2 MB 20.3 MB/s eta 0:00:05
#    -- ------------------------------------- 5.4/101.2 MB 20.2 MB/s eta 0:00:05
# ...

# %%
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Create dataset for CatBoost
dtrain = cb.Pool(X_train_sc, label=y_train)
dtest = cb.Pool(X_test_sc, label=y_test)

# Set up the parameters for the CatBoost model
params = {
    'iterations': 100,
    'learning_rate': 0.1,
    'depth': 6,
    'eval_metric': 'RMSE',
    'random_seed': 42,
    'logging_level': 'Verbose',
    'loss_function': 'RMSE'
}

# Train the model
model = cb.CatBoostRegressor(**params)
model.fit(dtrain, eval_set=dtest, verbose=False)

# Make predictions
preds = model.predict(X_test)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# bestTest = 4.25181815
# bestIteration = 99
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File _catboost.pyx:2383, in _catboost.get_float_feature()
#
# File _catboost.pyx:1188, in _catboost._FloatOrNan()
#
# File _catboost.pyx:983, in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'Cloudy'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# Cell In[78], line 27
#      24 model.fit(dtrain, eval_set=dtest, verbose=False)
#      26 # Make predictions
# ---> 27 preds = model.predict(X_test)
#      29 # Evaluate the model
#      30 rmse = mean_squared_error(y_test, preds, squared=False)
#
# ...

# %% [markdown]
# without knn sc

# %%
import catboost as cb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler



# Create dataset for CatBoost
dtrain = cb.Pool(X_train_sc, label=y_train)
dtest = cb.Pool(X_test_sc, label=y_test)

# Set up the parameters for the CatBoost model
params = {
    'iterations': 100,
    'learning_rate': 0.1,
    'depth': 6,
    'eval_metric': 'RMSE',
    'random_seed': 42,
    'logging_level': 'Verbose',
    'loss_function': 'RMSE'
}

# Train the model
model = cb.CatBoostRegressor(**params)
model.fit(dtrain, eval_set=dtest, verbose=False)

# Make predictions
preds = model.predict(X_test_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# bestTest = 4.25181815
# bestIteration = 99
#
# RMSE: 4.25
# R² Score: 0.80

# %% [markdown]
# with knn sc

# %%
import catboost as cb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler



# Create dataset for CatBoost
dtrain = cb.Pool(X_train_knn_sc, label=y_train)
dtest = cb.Pool(X_test_knn_sc, label=y_test)

# Set up the parameters for the CatBoost model
params = {
    'iterations': 100,
    'learning_rate': 0.1,
    'depth': 6,
    'eval_metric': 'RMSE',
    'random_seed': 42,
    'logging_level': 'Verbose',
    'loss_function': 'RMSE'
}

# Train the model
model = cb.CatBoostRegressor(**params)
model.fit(dtrain, eval_set=dtest, verbose=False)

# Make predictions
preds = model.predict(X_test_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# bestTest = 4.23680072
# bestIteration = 99
#
# RMSE: 4.33
# R² Score: 0.79

# %% [markdown]
# # Randomforest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train_knn,y_train)
prd=model.predict(X_test_knn)
# Out:
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
r2_score(y_test, prd)
# Out:
# 0.8090364468014721

# %%
from sklearn.model_selection import cross_validate

# %%
cv=cross_validate(estimator=model,X=X_train_knn,y=y_train)
# Out:
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# # Hyperparameter Tunning

# %%
pip install hyperopt
# Out:
# ...
#
#   Obtaining dependency information for hyperopt from https://files.pythonhosted.org/packages/b6/cd/5b3334d39276067f54618ce0d0b48ed69d91352fbf137468c7095170d0e5/hyperopt-0.2.7-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cloudpickle from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for py4j from https://files.pythonhosted.org/packages/10/30/a58b32568f1623aaad7db22aa9eafc4c6c194b429ff35bdc55ca2726da47/py4j-0.10.9.7-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.6 MB 660.6 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.6 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 10.1 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Including NaN values

# %% [markdown]
# # XGboost

# %% [markdown]
# without knn sc

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler


# Define the hyperparameter space
space = {
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'gamma': hp.loguniform('gamma', -5, 1),
    'reg_alpha': hp.loguniform('reg_alpha', -5, 1),
    'reg_lambda': hp.loguniform('reg_lambda', -5, 1),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)
}

def objective(params):
    params['max_depth'] = int(params['max_depth'])
    params['n_estimators'] = int(params['n_estimators'])
    model = xgb.XGBRegressor(**params, objective='reg:squarederror', seed=42)
    model.fit(X_train_sc, y_train)
    preds = model.predict(X_test_sc)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['max_depth'] = int(best_params['max_depth'])
best_params['n_estimators'] = int(best_params['n_estimators'])

# Train the final model with the best hyperparameters
model = xgb.XGBRegressor(**best_params, objective='reg:squarederror', seed=42)
model.fit(X_train_sc, y_train)

# Make predictions
preds = model.predict(X_test_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# 100%|██████████| 100/100 [01:50<00:00,  1.10s/trial, best loss: 3.9765234726471577]
# Best Parameters: {'colsample_bytree': 0.6463327111742024, 'gamma': 0.5854320034401609, 'learning_rate': 0.09790734971044061, 'max_depth': 8, 'n_estimators': 100, 'reg_alpha': 1.0597187428020571, 'reg_lambda': 0.28634968886361917, 'subsample': 0.9803321348498979}
# RMSE: 3.98
# R² Score: 0.82

# %% [markdown]
# with knn sc

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler


# Define the hyperparameter space
space = {
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'gamma': hp.loguniform('gamma', -5, 1),
    'reg_alpha': hp.loguniform('reg_alpha', -5, 1),
    'reg_lambda': hp.loguniform('reg_lambda', -5, 1),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)
}

def objective(params):
    params['max_depth'] = int(params['max_depth'])
    params['n_estimators'] = int(params['n_estimators'])
    model = xgb.XGBRegressor(**params, objective='reg:squarederror', seed=42)
    model.fit(X_train_knn_sc, y_train)
    preds = model.predict(X_test_knn_sc)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['max_depth'] = int(best_params['max_depth'])
best_params['n_estimators'] = int(best_params['n_estimators'])

# Train the final model with the best hyperparameters
model = xgb.XGBRegressor(**best_params, objective='reg:squarederror', seed=42)
model.fit(X_train_sc, y_train)

# Make predictions
preds = model.predict(X_test_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# 100%|██████████| 100/100 [01:32<00:00,  1.08trial/s, best loss: 3.9848672035694013]
# Best Parameters: {'colsample_bytree': 0.7795246287336308, 'gamma': 0.06999043494946117, 'learning_rate': 0.0630072791717691, 'max_depth': 9, 'n_estimators': 150, 'reg_alpha': 0.10823069601835694, 'reg_lambda': 0.054040610971451526, 'subsample': 0.9388672099851526}
# RMSE: 3.96
# R² Score: 0.82

# %% [markdown]
# # Catboost

# %% [markdown]
# without knn sc

# %%
import catboost as cb

# Define the objective function
def objective(params):
    params['iterations'] = int(params['iterations'])
    params['depth'] = int(params['depth'])
    model = cb.CatBoostRegressor(**params, verbose=0)
    model.fit(X_train_sc, y_train)
    preds = model.predict(X_test_sc)
    loss = mean_squared_error(y_test, preds)
    return {'loss': loss, 'status': STATUS_OK}

# Define the hyperparameter space
space = {
    'iterations': hp.quniform('iterations', 100, 1000, 100),
    'depth': hp.quniform('depth', 3, 10, 1),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'l2_leaf_reg': hp.uniform('l2_leaf_reg', 1, 10),
    'bagging_temperature': hp.uniform('bagging_temperature', 0, 1),
    'random_strength': hp.uniform('random_strength', 1, 20)
}

# Run the optimization
trials = Trials()
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
print("Best parameters:", best)
# Out:
# 100%|██████████| 50/50 [03:43<00:00,  4.47s/trial, best loss: 15.562516367789398]
# Best parameters: {'bagging_temperature': 0.9976743320121271, 'depth': 8.0, 'iterations': 900.0, 'l2_leaf_reg': 4.33105588973431, 'learning_rate': 0.053414639014255194, 'random_strength': 4.564406020237619}

# %%
model = cb.CatBoostRegressor(**best, verbose=0)
model.fit(X_train_sc, y_train)

# Make predictions on the test set
preds = model.predict(X_test_sc)

# Evaluate the final model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)

print(f'Best Parameters: {best}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'bagging_temperature': 0.9976743320121271, 'depth': 8.0, 'iterations': 900.0, 'l2_leaf_reg': 4.33105588973431, 'learning_rate': 0.053414639014255194, 'random_strength': 4.564406020237619}
# RMSE: 3.94
# R² Score: 0.82

# %% [markdown]
# with knn sc

# %%
import catboost as cb

# Define the objective function
def objective(params):
    params['iterations'] = int(params['iterations'])
    params['depth'] = int(params['depth'])
    model = cb.CatBoostRegressor(**params, verbose=0)
    model.fit(X_train_knn_sc, y_train)
    preds = model.predict(X_test_knn_sc)
    loss = mean_squared_error(y_test, preds)
    return {'loss': loss, 'status': STATUS_OK}

# Define the hyperparameter space
space = {
    'iterations': hp.quniform('iterations', 100, 1000, 100),
    'depth': hp.quniform('depth', 3, 10, 1),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'l2_leaf_reg': hp.uniform('l2_leaf_reg', 1, 10),
    'bagging_temperature': hp.uniform('bagging_temperature', 0, 1),
    'random_strength': hp.uniform('random_strength', 1, 20)
}

# Run the optimization
trials = Trials()
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
print("Best parameters:", best)
# Out:
# 100%|██████████| 50/50 [02:02<00:00,  2.44s/trial, best loss: 15.590463367559625]
# Best parameters: {'bagging_temperature': 0.19785249385117382, 'depth': 9.0, 'iterations': 300.0, 'l2_leaf_reg': 1.4221997712982581, 'learning_rate': 0.092474015186268, 'random_strength': 1.0370023428310648}

# %%
model = cb.CatBoostRegressor(**best, verbose=0)
model.fit(X_train_sc, y_train)

# Make predictions on the test set
preds = model.predict(X_test_sc)

# Evaluate the final model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)

print(f'Best Parameters: {best}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'bagging_temperature': 0.19785249385117382, 'depth': 9.0, 'iterations': 300.0, 'l2_leaf_reg': 1.4221997712982581, 'learning_rate': 0.092474015186268, 'random_strength': 1.0370023428310648}
# RMSE: 3.96
# R² Score: 0.82

# %% [markdown]
# # Lightgbm

# %% [markdown]
# without knn sc

# %%
import lightgbm as lgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Define the hyperparameter space
space = {
    'num_leaves': hp.quniform('num_leaves', 20, 150, 5),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'min_child_weight': hp.loguniform('min_child_weight', -3, 2),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)
}

def objective(params):
    params['num_leaves'] = int(params['num_leaves'])
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    model = lgb.LGBMRegressor(**params, objective='regression', seed=42)
    model.fit(X_train_sc, y_train, eval_set=[(X_test_sc, y_test)])
    preds = model.predict(X_test_sc, num_iteration=model.best_iteration_)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['num_leaves'] = int(best_params['num_leaves'])
best_params['n_estimators'] = int(best_params['n_estimators'])
best_params['max_depth'] = int(best_params['max_depth'])



# Train the final model with the best hyperparameters
model = lgb.LGBMRegressor(**best_params, objective='regression', seed=42)
model.fit(X_train_sc, y_train)

# Make predictions
preds = model.predict(X_test_sc, num_iteration=model.best_iteration_)

# Evaluate the model
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# job exception: name 'X_train_sc' is not defined
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 29
#      27 # Optimize the hyperparameters
#      28 trials = Trials()
# ---> 29 best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)
#      32 # Evaluate the model
#
# File c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# ...

# %%
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'colsample_bytree': 0.9112803748053011, 'learning_rate': 0.05358846809083, 'max_depth': 13, 'min_child_weight': 0.11668355439870165, 'n_estimators': 100, 'num_leaves': 140, 'subsample': 0.6038521543602385}
# RMSE: 3.89
# R² Score: 0.83

# %% [markdown]
# with knn sc

# %%
import lightgbm as lgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Define the hyperparameter space
space = {
    'num_leaves': hp.quniform('num_leaves', 20, 150, 5),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'min_child_weight': hp.loguniform('min_child_weight', -3, 2),
    'subsample': hp.uniform('subsample', 0.5, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)
}

def objective(params):
    params['num_leaves'] = int(params['num_leaves'])
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    model = lgb.LGBMRegressor(**params, objective='regression', seed=42)
    model.fit(X_train_knn_sc, y_train, eval_set=[(X_test_knn_sc, y_test)])
    preds = model.predict(X_test_sc, num_iteration=model.best_iteration_)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['num_leaves'] = int(best_params['num_leaves'])
best_params['n_estimators'] = int(best_params['n_estimators'])
best_params['max_depth'] = int(best_params['max_depth'])



# Train the final model with the best hyperparameters
model = lgb.LGBMRegressor(**best_params, objective='regression', seed=42)
model.fit(X_train_sc, y_train)

# Make predictions
preds = model.predict(X_test_sc, num_iteration=model.best_iteration_)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001477 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 807
# [LightGBM] [Info] Number of data points in the train set: 31908, number of used features: 28
# [LightGBM] [Info] Start training from score 26.277924
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'colsample_bytree': 0.9073987966526903, 'learning_rate': 0.05937261694644413, 'max_depth': 12, 'min_child_weight': 0.724119860223626, 'n_estimators': 200, 'num_leaves': 115, 'subsample': 0.7715945460864448}
# RMSE: 3.90
# R² Score: 0.83

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np



# Define the hyperparameter space
space = {
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'min_samples_split': hp.quniform('min_samples_split', 2, 10, 1),
    'min_samples_leaf': hp.quniform('min_samples_leaf', 1, 5, 1),
    'max_features': hp.uniform('max_features', 0.5, 1.0)
}

def objective(params):
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    params['min_samples_split'] = int(params['min_samples_split'])
    params['min_samples_leaf'] = int(params['min_samples_leaf'])
    model = RandomForestRegressor(**params, random_state=42)
    model.fit(X_train_knn_sc, y_train)
    preds = model.predict(X_test_knn_sc)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['n_estimators'] = int(best_params['n_estimators'])
best_params['max_depth'] = int(best_params['max_depth'])
best_params['min_samples_split'] = int(best_params['min_samples_split'])
best_params['min_samples_leaf'] = int(best_params['min_samples_leaf'])

# Train the final model with the best hyperparameters
model = RandomForestRegressor(**best_params, random_state=42)
model.fit(X_train_knn_sc, y_train)

# Make predictions
preds = model.predict(X_test_knn_sc)
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
#   1%|          | 1/100 [00:16<27:15, 16.52s/trial, best loss: 4.557000690204865]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
#   2%|▏         | 2/100 [00:51<44:33, 27.28s/trial, best loss: 4.24450430670044]
# ...

# %%
# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'max_depth': 16, 'max_features': 0.5432096766973807, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 900}
# RMSE: 4.00
# R² Score: 0.82

# %% [markdown]
# # GradientBoosting

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials


# Define the hyperparameter space
space = {
    'n_estimators': hp.quniform('n_estimators', 100, 1000, 50),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'max_depth': hp.quniform('max_depth', 3, 18, 1),
    'min_samples_split': hp.quniform('min_samples_split', 2, 10, 1),
    'min_samples_leaf': hp.quniform('min_samples_leaf', 1, 5, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'max_features': hp.uniform('max_features', 0.5, 1.0)
}

def objective(params):
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    params['min_samples_split'] = int(params['min_samples_split'])
    params['min_samples_leaf'] = int(params['min_samples_leaf'])
    model = GradientBoostingRegressor(**params, random_state=42)
    model.fit(X_train_knn_sc, y_train)
    preds = model.predict(X_test_knn_sc)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['n_estimators'] = int(best_params['n_estimators'])
best_params['max_depth'] = int(best_params['max_depth'])
best_params['min_samples_split'] = int(best_params['min_samples_split'])
best_params['min_samples_leaf'] = int(best_params['min_samples_leaf'])

# Train the final model with the best hyperparameters
model = GradientBoostingRegressor(**best_params, random_state=42)
model.fit(X_train_knn_sc, y_train)

# Make predictions
preds = model.predict(X_test_knn_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   1%|          | 1/100 [00:56<1:33:44, 56.82s/trial, best loss: 4.152614064937191]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   2%|▏         | 2/100 [01:38<1:18:39, 48.15s/trial, best loss: 4.152614064937191]
# ...

# %% [markdown]
# # Adaboost

# %%
import numpy as np

from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials


# Define the hyperparameter space
space = {
    'n_estimators': hp.quniform('n_estimators', 50, 500, 50),
    'learning_rate': hp.loguniform('learning_rate', -3, 0)
}

def objective(params):
    params['n_estimators'] = int(params['n_estimators'])
    model = AdaBoostRegressor(**params, random_state=42)
    model.fit(X_train_knn_sc, y_train)
    preds = model.predict(X_test_knn_sc)
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {'loss': rmse, 'status': STATUS_OK}

# Optimize the hyperparameters
trials = Trials()
best_params = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100, trials=trials)

# Convert best_params to the appropriate types
best_params['n_estimators'] = int(best_params['n_estimators'])

# Train the final model with the best hyperparameters
model = AdaBoostRegressor(**best_params, random_state=42)
model.fit(X_train_knn_sc, y_train)

# Make predictions
preds = model.predict(X_test_knn_sc)

# Evaluate the model
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   1%|          | 1/100 [00:05<09:03,  5.49s/trial, best loss: 6.253791273458079]
# c:\Users\new\anaconda3\envs\EDA_practice\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#   2%|▏         | 2/100 [00:08<06:17,  3.86s/trial, best loss: 6.253791273458079]
# ...

# %%
rmse = mean_squared_error(y_test, preds, squared=False)
r2 = r2_score(y_test, preds)
print(f'Best Parameters: {best_params}')
print(f'RMSE: {rmse:.2f}')
print(f'R² Score: {r2:.2f}')
# Out:
# Best Parameters: {'learning_rate': 0.5506040624081123, 'n_estimators': 400}
# RMSE: 6.15
# R² Score: 0.57
